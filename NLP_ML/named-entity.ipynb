# %%
#Named-entity recogintion

# %%
sentences='''Here are 32 questions most asked DSA questions that you should visit 
If you are preparing to switch jobs. 


1. Reverse a linked list
2. Find the middle element of a linked list
3. Detect a cycle in a linked list
4. Find the intersection point of two linked lists
5. Check if a binary tree is a binary search tree (BST)
6. Find the largest/smallest element in an array
7. Implement depth-first search (DFS) on a graph
8. Implement breadth-first search (BFS) on a graph
9. Implement binary search in an array
10. Find the kth smallest/largest element in an array
11. Find the longest common subsequence of two strings
12. Implement merge sort
13. Implement quick sort
14. Implement Dijkstra's algorithm for the shortest path
15. Find the longest palindrome substring in a string
16. Find the median of two sorted arrays
17. Check if two strings are anagrams of each other
18. Implement a trie (prefix tree)
19. Implement an LRU (Least Recently Used) Cache
20. Find all permutations of a string
21. Implement a stack using arrays/linked list
22. Implement a queue using arrays/linked list
23. Implement a priority queue
24. Implement Kruskal's algorithm for minimum spanning tree
25. Implement Prim's algorithm for minimum spanning tree
26. Count the number of inversions in an array
27. Find the shortest path in a maze
28. Find all subsets of a set
29. Find the longest substring without repeating characters
30. Implement the Knuth–Morris–Pratt (KMP) algorithm for string matching
31. Implement the Rabin-Karp algorithm for string matching
32. Implement the Josephus Problem
'''

# %%
import nltk
words=nltk.word_tokenize(sentences)#break snetences into word

# %%
tagged=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/aryaman/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /home/aryaman/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.ne_chunk(tagged)
#nltk.ne_chunk(tagged).draw()
# Out:
# Tree('S', [('Here', 'RB'), ('are', 'VBP'), ('32', 'CD'), ('questions', 'NNS'), ('most', 'RBS'), ('asked', 'JJ'), Tree('ORGANIZATION', [('DSA', 'NNP')]), ('questions', 'NNS'), ('that', 'IN'), ('you', 'PRP'), ('should', 'MD'), ('visit', 'VB'), ('If', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('preparing', 'VBG'), ('to', 'TO'), ('switch', 'VB'), ('jobs', 'NNS'), ('.', '.'), ('1', 'CD'), ('.', '.'), ('Reverse', 'VB'), ('a', 'DT'), ('linked', 'VBN'), ('list', 'NN'), ('2', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('middle', 'JJ'), ('element', 'NN'), ('of', 'IN'), ('a', 'DT'), ('linked', 'VBN'), ('list', 'NN'), ('3', 'CD'), ('.', '.'), ('Detect', 'VB'), ('a', 'DT'), ('cycle', 'NN'), ('in', 'IN'), ('a', 'DT'), ('linked', 'VBN'), ('list', 'NN'), ('4', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('intersection', 'NN'), ('point', 'NN'), ('of', 'IN'), ('two', 'CD'), ('linked', 'JJ'), ('lists', 'NNS'), ('5', 'CD'), ('.', '.'), ('Check', 'VB'), ('if', 'IN'), ('a', 'DT'), ('binary', 'JJ'), ('tree', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('binary', 'JJ'), ('search', 'NN'), ('tree', 'NN'), ('(', '('), Tree('ORGANIZATION', [('BST', 'NNP')]), (')', ')'), ('6', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('largest/smallest', 'JJS'), ('element', 'NN'), ('in', 'IN'), ('an', 'DT'), ('array', 'NN'), ('7', 'CD'), ('.', '.'), ('Implement', 'JJ'), ('depth-first', 'JJ'), ('search', 'NN'), ('(', '('), Tree('ORGANIZATION', [('DFS', 'NNP')]), (')', ')'), ('on', 'IN'), ('a', 'DT'), ('graph', 'NN'), ('8', 'CD'), ('.', '.'), ('Implement', 'JJ'), ('breadth-first', 'JJ'), ('search', 'NN'), ('(', '('), Tree('ORGANIZATION', [('BFS', 'NNP')]), (')', ')'), ('on', 'IN'), ('a', 'DT'), ('graph', 'NN'), ('9', 'CD'), ('.', '.'), ('Implement', 'NNP'), ('binary', 'JJ'), ('search', 'NN'), ('in', 'IN'), ('an', 'DT'), ('array', 'NN'), ('10', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('kth', 'NN'), ('smallest/largest', 'JJS'), ('element', 'NN'), ('in', 'IN'), ('an', 'DT'), ('array', 'NN'), ('11', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('longest', 'JJS'), ('common', 'JJ'), ('subsequence', 'NN'), ('of', 'IN'), ('two', 'CD'), ('strings', 'NNS'), ('12', 'CD'), ('.', '.'), ('Implement', 'NNP'), ('merge', 'NN'), ('sort', 'NN'), ('13', 'CD'), ('.', '.'), ('Implement', 'NNP'), ('quick', 'JJ'), ('sort', 'NN'), ('14', 'CD'), ('.', '.'), Tree('PERSON', [('Implement', 'NNP'), ('Dijkstra', 'NNP')]), ("'s", 'POS'), ('algorithm', 'NN'), ('for', 'IN'), ('the', 'DT'), ('shortest', 'JJS'), ('path', 'NN'), ('15', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('longest', 'JJS'), ('palindrome', 'NN'), ('substring', 'NN'), ('in', 'IN'), ('a', 'DT'), ('string', 'NN'), ('16', 'CD'), ('.', '.'), ('Find', 'VB'), ('the', 'DT'), ('median', 'NN'), ('of', 'IN'), ('two', 'CD'), ('sorted', 'VBD'), ('arrays', 'NNS'), ('17', 'CD'), ('.', '.'), ('Check', 'VB'), ('if', 'IN'), ('two', 'CD'), ('strings', 'NNS'), ('are', 'VBP'), ('anagrams', 'NNS'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('18', 'CD'), ('.', '.'), ('Implement', 'VB'), ('a', 'DT'), ('trie', 'NN'), ('(', '('), ('prefix', 'JJ'), ('tree', 'NN'), (')', ')'), ('19', 'CD'), ('.', '.'), ('Implement', 'NNP'), ('an', 'DT'), ('LRU', 'NNP'), ('(', '('), Tree('ORGANIZATION', [('Least', 'NNP'), ('Recently', 'NNP')]), ('Used', 'VBD'), (')', ')'), ('Cache', 'NNP'), ('20', 'CD'), ('.', '.'), ('Find', 'VB'), ('all', 'DT'), ('permutations', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('string', 'NN'), ('21', 'CD'), ('.', '.'), ('Implement', 'VB'), ('a', 'DT'), ('stack', 'NN'), ('using', 'VBG'), ('arrays/linked', 'JJ'), ('list', 'NN'), ('22', 'CD'), ('.', '.'), ('Implement', 'VB'), ('a', 'DT'), ('queue', 'NN'), ('using', 'VBG'), ('arrays/linked', 'JJ'), ('list', 'NN'), ('23', 'CD'), ('.', '.'), ('Implement', 'VB'), ('a', 'DT'), ('priority', 'NN'), ('queue', 'RB'), ('24', 'CD'), ('.', '.'), Tree('PERSON', [('Implement', 'NNP'), ('Kruskal', 'NNP')]), ("'s", 'POS'), ('algorithm', 'NN'), ('for', 'IN'), ('minimum', 'JJ'), ('spanning', 'JJ ...
